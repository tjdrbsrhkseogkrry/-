# %% [markdown]
# <a href="https://colab.research.google.com/github/tjdrbsrhkseogkrry/-/blob/main/Chapter2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Chapter 2-1***

# %%
d = {"name" : "혼자 공부하는 데이터 분석"}
print(d['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
import json
d_str = json.dumps(d, ensure_ascii=False)
print(d_str)
#기본적으로 json.dumps()함수는 아스키 문자 외의 다른 문자를 16진수로 출력하므로 한글이 제대로 보이지 않음.
# Out:
# {"name": "혼자 공부하는 데이터 분석"}

# %%
d2 = json.loads(d_str)
print(d2['name'])
print(type(d2))
# Out:
# 혼자 공부하는 데이터 분석
# <class 'dict'>

# %%
d3 = json.loads('{"name":"혼자 공부하는 데이터 분석","author":"박해선","year":2022}')
print(d3['name'])
print(d3['author'])
print(d3['year'])
# Out:
# 혼자 공부하는 데이터 분석
# 박해선
# 2022

# %%
d3 = json.loads('{"name":"혼자 공부하는 데이터 분석","author":["박해선","홍길동"],"year":2022}')
print(d3['author'][1])
# Out:
# 홍길동

# %%
d4_str = """
[
  {"name":"혼자 공부하는 데이터 분석","author":"박해선","year":2022},
  {"name":"혼자 공부하는 머신러닝+딥러닝","author":"박해선","year":2020}
]
"""
d4 = json.loads(d4_str)
print(d4[0]['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
from io import StringIO
import pandas as pd
pd.read_json(StringIO(d4_str))
# Out:
#                name author  year
# 0    혼자 공부하는 데이터 분석    박해선  2022
# 1  혼자 공부하는 머신러닝+딥러닝    박해선  2020

# %%
x_str = """
<book>
  <name>혼자 공부하는 데이터 분석</name>
  <author>박해선</author>
  <year>2022</year>
</book>
"""
import xml.etree.ElementTree as et
book = et.fromstring(x_str)
print(type(book))
# Out:
# <class 'xml.etree.ElementTree.Element'>

# %%
book_childs = list(book)
print(book_childs)
# Out:
# [<Element 'name' at 0x7c5d7d1efdd0>, <Element 'author' at 0x7c5d7d1efe20>, <Element 'year' at 0x7c5d7d1efe70>]

# %%
name, author, year = book_childs
print(name.text)
print(author.text)
print(year.text)
# Out:
# 혼자 공부하는 데이터 분석
# 박해선
# 2022

# %%
name = book.findtext('name')
author = book.findtext('author')
year =  book.findtext('year')
print(name)
print(author)
print(year)
# Out:
# 혼자 공부하는 데이터 분석
# 박해선
# 2022

# %%
x2_str = """
<books>
  <book>
    <name>혼자 공부하는 데이터 분석,혼자 공부하는 파이썬</name>
    <author>박해선</author>
    <year>2022</year>
  </book>
  <book>
    <name>혼자 공부하는 머신러닝+딥러닝</name>
    <author>박해선</author>
    <year>2020</year>
  </book>
</books>
"""
books = et.fromstring(x2_str)
print(books.tag)
# Out:
# books

# %%
for book in books.findall('book'):
  name = book.findtext('name')
  author = book.findtext('author')
  year = book.findtext('year')
  print(name)
  print(author)
  print(year)
  print()
# Out:
# 혼자 공부하는 데이터 분석,혼자 공부하는 파이썬
# 박해선
# 2022
#
# 혼자 공부하는 머신러닝+딥러닝
# 박해선
# 2020

# %%
from io import StringIO
import pandas as pd
pd.read_xml(StringIO(x2_str))
# Out:
#                          name author  year
# 0  혼자 공부하는 데이터 분석,혼자 공부하는 파이썬    박해선  2022
# 1            혼자 공부하는 머신러닝+딥러닝    박해선  2020

# %%
import requests
url = "http://data4library.kr/api/loanItemSrch?format=json&startDt=2021-04-01&endDt=2021-04-30&age=20&authKey=67faeec8435bea61464fd9d1580479e837f46149491676c1dbb2085c059fea97"
r=requests.get(url)
data= r.json()
print(data)
# Out:
# {'response': {'request': {'startDt': '2021-04-01', 'endDt': '2021-04-30', 'age': '20', 'pageNo': 1, 'pageSize': 200}, 'resultNum': 200, 'numFound': 5000, 'docs': [{'doc': {'no': 1, 'ranking': '1', 'bookname': '우리가 빛의 속도로 갈 수 없다면 :김초엽 소설 ', 'authors': '지은이: 김초엽', 'publisher': '허블', 'publication_year': '2019', 'isbn13': '9791190090018', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.7', 'class_nm': '문학 > 한국문학 > 소설', 'bookImageURL': 'https://image.aladin.co.kr/product/19359/16/cover/s972635417_1.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=5430429'}}, {'doc': {'no': 2, 'ranking': '2', 'bookname': '달러구트 꿈 백화점 :주문하신 꿈은 매진입니다 ', 'authors': '지은이: 이미예', 'publisher': '팩토리나인', 'publication_year': '2020', 'isbn13': '9791165341909', 'addition_symbol': '03810', 'vol': '', 'class_no': '813.7', 'class_nm': '문학 > 한국문학 > 소설', 'bookImageURL': 'https://image.aladin.co.kr/product/24512/70/cover/k392630952_1.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=5707051'}}, {'doc': {'n
# ...

# %%
data
# Out:
# {'response': {'request': {'startDt': '2021-04-01',
#    'endDt': '2021-04-30',
#    'age': '20',
#    'pageNo': 1,
#    'pageSize': 200},
#   'resultNum': 200,
#   'numFound': 5000,
#   'docs': [{'doc': {'no': 1,
#      'ranking': '1',
#      'bookname': '우리가 빛의 속도로 갈 수 없다면 :김초엽 소설 ',
#      'authors': '지은이: 김초엽',
#      'publisher': '허블',
#      'publication_year': '2019',
#      'isbn13': '9791190090018',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
#      'class_nm': '문학 > 한국문학 > 소설',
#      'bookImageURL': 'https://image.aladin.co.kr/product/19359/16/cover/s972635417_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=5430429'}},
#    {'doc': {'no': 2,
#      'ranking': '2',
#      'bookname': '달러구트 꿈 백화점 :주문하신 꿈은 매진입니다 ',
#      'authors': '지은이: 이미예',
#      'publisher': '팩토리나인',
#      'publication_year': '2020',
#      'isbn13': '9791165341909',
#      'addition_symbol': '03810',
#      'vol': '',
#      'class_no': '813.7',
# ...

# %%
books = []
for d in data['response']['docs']:
  books.append(d['doc'])

# %%
books
# Out:
# [{'no': 1,
#   'ranking': '1',
#   'bookname': '우리가 빛의 속도로 갈 수 없다면 :김초엽 소설 ',
#   'authors': '지은이: 김초엽',
#   'publisher': '허블',
#   'publication_year': '2019',
#   'isbn13': '9791190090018',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'bookImageURL': 'https://image.aladin.co.kr/product/19359/16/cover/s972635417_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5430429'},
#  {'no': 2,
#   'ranking': '2',
#   'bookname': '달러구트 꿈 백화점 :주문하신 꿈은 매진입니다 ',
#   'authors': '지은이: 이미예',
#   'publisher': '팩토리나인',
#   'publication_year': '2020',
#   'isbn13': '9791165341909',
#   'addition_symbol': '03810',
#   'vol': '',
#   'class_no': '813.7',
#   'class_nm': '문학 > 한국문학 > 소설',
#   'bookImageURL': 'https://image.aladin.co.kr/product/24512/70/cover/k392630952_1.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=5707051'},
#  {'no': 3,
#   'ranking': '3',
#   'bookname': '지구에서 한아뿐 :정세랑 장편소설 ',
# ...

# %%
import pandas as pd
books_df = pd.DataFrame(books)
books_df
# Out:
#       no ranking                                     bookname  \
# 0      1       1                  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설
# 1      2       2                   달러구트 꿈 백화점 :주문하신 꿈은 매진입니다
# 2      3       3                          지구에서 한아뿐 :정세랑 장편소설
# 3      4       4                           시선으로부터, :정세랑 장편소설
# 4      5       5                                  아몬드손원평 장편소설
# ..   ...     ...                                          ...
# 195  196     195                                          심판
# 196  197     195  지리의 힘 :지리는 어떻게 개인의 운명을, 세계사를, 세계 경제를 좌우하는가
# 197  198     195                      오베라는 남자 :프레드릭 배크만 장편소설
# 198  199     195                              (걸어 다니는) 어원 사전
# 199  200     195                                      열두 발자국
#
#                      authors publisher publication_year         isbn13  \
# 0                   지은이: 김초엽        허블             2019  9791190090018
# 1                   지은이: 이미예     팩토리나인             2020  9791165341909
# ...

# %%
books_df.to_json('20s_best_book.json')

# %% [markdown]
# # ***Chaper 2-2***

# %%
import gdown
gdown.download('http://bit.ly/3q9SZix', '20s_best_book.json', quiet=False)
# Out:
# Downloading...
# From: http://bit.ly/3q9SZix
# To: /content/20s_best_book.json
# 100%|██████████| 92.9k/92.9k [00:00<00:00, 2.64MB/s]
# '20s_best_book.json'

# %%
import pandas as pd
books_df.head()
# Out:
#    no ranking                     bookname   authors publisher  \
# 0   1       1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   2       2   달러구트 꿈 백화점 :주문하신 꿈은 매진입니다   지은이: 이미예     팩토리나인
# 2   3       3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 3   4       4           시선으로부터, :정세랑 장편소설   지은이: 정세랑      문학동네
# 4   5       5                  아몬드손원평 장편소설       손원평        창비
#
#   publication_year         isbn13 addition_symbol vol class_no  \
# 0             2019  9791190090018           03810        813.7
# 1             2020  9791165341909           03810        813.7
# 2             2019  9791188862290           03810        813.7
# 3             2020  9788954672214           03810        813.7
# 4       2017-03-31  9788936434267           03810        813.7
#
#          class_nm                                       bookImageURL  \
# 0  문학 > 한국문학 > 소설  https://image.aladin.co.kr/product/19359/16/co...
# ...

# %%
books = books_df[['no','ranking','bookname','authors','publisher','publication_year','isbn13']]
books.head()
# Out:
#    no ranking                     bookname   authors publisher  \
# 0   1       1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   2       2   달러구트 꿈 백화점 :주문하신 꿈은 매진입니다   지은이: 이미예     팩토리나인
# 2   3       3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 3   4       4           시선으로부터, :정세랑 장편소설   지은이: 정세랑      문학동네
# 4   5       5                  아몬드손원평 장편소설       손원평        창비
#
#   publication_year         isbn13
# 0             2019  9791190090018
# 1             2020  9791165341909
# 2             2019  9791188862290
# 3             2020  9788954672214
# 4       2017-03-31  9788936434267

# %%
books_df.loc[[0,1],'bookname':'publisher']
# Out:
#                       bookname   authors publisher
# 0  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   달러구트 꿈 백화점 :주문하신 꿈은 매진입니다   지은이: 이미예     팩토리나인

# %%
books_df.loc[::2,'bookname':'publisher']
# Out:
#                                               bookname  \
# 0                          우리가 빛의 속도로 갈 수 없다면 :김초엽 소설
# 2                                  지구에서 한아뿐 :정세랑 장편소설
# 4                                          아몬드손원평 장편소설
# 6                                    피프티 피플 :정세랑 장편소설
# 8                                   천 개의 파랑 :천선란 장편소설
# ..                                                 ...
# 190                                           두 번째 엔딩
# 192  박막례, 이대로 죽을 순 없다 :독보적 유튜버 박막례와 천재 PD 손녀 김유라의 말...
# 194                                죽음 :베르나르 베르베르 장편소설
# 196        지리의 힘 :지리는 어떻게 개인의 운명을, 세계사를, 세계 경제를 좌우하는가
# 198                                    (걸어 다니는) 어원 사전
#
#                       authors     publisher
# 0                    지은이: 김초엽            허블
# 2                    지은이: 정세랑            난다
# 4                         손원평            창비
# 6                    지은이: 정세랑            창비
# 8                    지은이: 천선란            허블
# ...

# %%
import requests
isbn = 9791162243664
url = 'https://www.yes24.com/Product/Search?domain=BOOK&query={}'
r= requests.get(url.format(isbn))
print(r.text)
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head>
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title> 9791162243664 - 예스24</title>
#
# 	<meta name="title" content="예스24" />
# 	<meta name="description" content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" />
# 	<meta name="keywords" content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘, 리센스, 예스24 도서용품, 친환경 PB 브랜드, 사은품, 굿즈" />
#
#
# 	<link title="YES24" rel="search" type="application/opensearchdescription+xml" href="//www.yes24.com/OpensearchDescription.xml">
#
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'html.parser')
prd_link = soup.find('a', attrs={'class':'gd_name'})
print(prd_link)
# Out:
# <a class="gd_name" href="/Product/Goods/96024871" onclick="wiseLogV2('S', '101_005_003_001', ''); setGoodsClickExtraCodeHub('032', '9791162243664', '96024871', '0',this);">혼자 공부하는 머신러닝+딥러닝</a>

# %%
url = 'http://www.yes24.com' + prd_link['href']
r=requests.get(url)
print(r.text)
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head><link rel="canonical" href="https://www.yes24.com/Product/Goods/96024871">
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title>혼자 공부하는 머신러닝+딥러닝 - 예스24 </title>
#
#
# <meta name="title" content="혼자 공부하는 머신러닝+딥러닝"/>
# <meta name="author" content="박해선 저" />
#
# <meta name="description" content="1:1 과외하듯 배우는 인공지능 자습서. 박해선 저. 한빛미디어. 구매혜택:분철 할인 쿠폰 증정. 판매가 23,400원(10% 할인). 포인트 1,300원(5% 적립). - 혼자 해도 충분하다! 1:1 과외하듯 배우는 인공지능 자습서 이 책은 수식과 이론으로 ..."/>
#
# ...

# %%
soup = BeautifulSoup(r.text, 'html.parser')
prd_info = soup.find('div', attrs={'id':'infoset_specific'})
print(prd_info)
# Out:
# <div class="gd_infoSet infoSet_noLine" id="infoset_specific">
# <div class="tm_infoSet">
# <h4 class="tit_txt">품목정보</h4>
# </div>
# <div class="infoSetCont_wrap">
# <div class="yesTb">
# <table class="tb_nor tb_vertical" summary="품목정보 국내도서, 외국도서 " width="100%">
# <caption>품목정보</caption>
# <colgroup>
# <col width="170"/>
# <col width="*"/>
# </colgroup>
# <tbody class="b_size">
# <tr>
# <th class="txt" scope="row">발행일</th>
# <td class="txt lastCol">2020년 12월 21일</td>
# </tr>
# <tr>
# <th class="txt" scope="row">쪽수, 무게, 크기</th>
# <td class="txt lastCol">580쪽 | 1,105g | 188*257mm</td>
# </tr>
# <tr>
# <th class="txt" scope="row">ISBN13</th>
# <td class="txt lastCol">9791162243664</td>
# </tr>
# <tr>
# <th class="txt" scope="row">ISBN10</th>
# <td class="txt lastCol">116224366X</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <script type="text/javascript">
#         if ($("#infoset_specific table tbody tr").length == 0) {
#             $("#infoset_specific").remove();
#         }
# ...

# %%
prd_tr_list = prd_info.find_all('tr')
print(prd_tr_list)
# Out:
# [<tr>
# <th class="txt" scope="row">발행일</th>
# <td class="txt lastCol">2020년 12월 21일</td>
# </tr>, <tr>
# <th class="txt" scope="row">쪽수, 무게, 크기</th>
# <td class="txt lastCol">580쪽 | 1,105g | 188*257mm</td>
# </tr>, <tr>
# <th class="txt" scope="row">ISBN13</th>
# <td class="txt lastCol">9791162243664</td>
# </tr>, <tr>
# <th class="txt" scope="row">ISBN10</th>
# <td class="txt lastCol">116224366X</td>
# </tr>]

# %%
for tr in prd_tr_list:
  if tr.find('th').get_text() == '쪽수, 무게, 크기':
    page_td = tr.find('td').get_text()
    break
print(page_td)
print(page_td.split()[0])
# Out:
# 580쪽 | 1,105g | 188*257mm
# 580쪽

# %%
def get_page_cnt(isbn):
  url = 'https://www.yes24.com/Product/Search?domain=BOOK&query={}'
  r = requests.get(url.format(isbn))
  soup = BeautifulSoup(r.text, 'html.parser')
  prd_link = soup.find('a', attrs={'class':'gd_name'})
  if prd_link is None:
    return ''
  url = 'http://www.yes24.com' + prd_link['href']
  r = requests.get(url)
  soup = BeautifulSoup(r.text, 'html.parser')
  prd_info = soup.find('div', attrs={'id':'infoset_specific'})
  prd_tr_list = prd_info.find_all('tr')
  for tr in prd_tr_list:
    if tr.find('th').get_text() == "쪽수, 무게, 크기":
      return tr.find('td').get_text().split()[0]
  return ''

get_page_cnt(9791190090018)
# Out:
# '330쪽'

# %%
top10_books =books.head(10)
def get_page_cnt2(row):
  isbn = row['isbn13']
  return get_page_cnt(isbn)
page_count = top10_books.apply(get_page_cnt2, axis=1)
print(page_count)
# Out:
# 0    330쪽
# 1    300쪽
# 2    228쪽
# 3    340쪽
# 4    264쪽
# 5    272쪽
# 6    396쪽
# 7
# 8    376쪽
# 9    244쪽
# dtype: object

# %%
page_count.name = 'page_count'
print(page_count)
# Out:
# 0    330쪽
# 1    300쪽
# 2    228쪽
# 3    340쪽
# 4    264쪽
# 5    272쪽
# 6    396쪽
# 7
# 8    376쪽
# 9    244쪽
# Name: page_count, dtype: object

# %%
top10_with_page_count = pd.merge(top10_books, page_count, left_index=True, right_index=True)
top10_with_page_count
# Out:
#    no ranking                     bookname                  authors publisher  \
# 0   1       1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설                  지은이: 김초엽        허블
# 1   2       2   달러구트 꿈 백화점 :주문하신 꿈은 매진입니다                  지은이: 이미예     팩토리나인
# 2   3       3          지구에서 한아뿐 :정세랑 장편소설                  지은이: 정세랑        난다
# 3   4       4           시선으로부터, :정세랑 장편소설                  지은이: 정세랑      문학동네
# 4   5       5                  아몬드손원평 장편소설                      손원평        창비
# 5   6       6          목소리를 드릴게요 :정세랑 소설집                  지은이: 정세랑        아작
# 6   7       7            피프티 피플 :정세랑 장편소설                  지은이: 정세랑        창비
# 7   8       8  나미야 잡화점의 기적 :히가시노 게이고 장편소설   지은이: 히가시노 게이고 ;옮긴이: 양윤옥      현대문학
# 8   9       9           천 개의 파랑 :천선란 장편소설                  지은이: 천선란        허블
# 9  10      10                   선량한 차별주의자                    김지혜 지음        창비
#
#   publication_year         isbn13 page_count
# 0             2019  9791190090018       330쪽
# ...
